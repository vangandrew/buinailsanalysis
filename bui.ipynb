# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.yelp.com/biz/bui-nails-lounge-lincoln?rr=1')

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" prefix="og: http://ogp.me/ns#" style="margin: 0;padding: 0; border: 0; font-size: 100%; font: inherit; vertical-align: baseline;"><head><script>document.documentElement.className=document.documentElement.className.replace(/\x08no-js\x08/,"js");</script><meta http-equiv="Content-Type" content="text/html; charset=UTF-8" /><meta http-equiv="Content-Language" content="en-US" /><meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><link rel="mask-icon" sizes="any" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/b2bb2fb0ec9c/assets/img/logos/yelp_burst.svg" content="#FF1A1A"><link rel="shortcut icon" href="https://s3-media0.fl.yelpcdn.com/assets/srv0/yelp_large_assets/dcfe403147fc/assets/img/logos/favicon.ico"><script> window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;window.ygaPageStartTime=new Date().getTime();</script><script>\n            window.yelp = window.yelp || {};\n            window.yelp.cookieTypePreferencesHeader = \'["ANALYTICS","FUNCTIONAL","INTERNAL","STRICTLY_NECESSARY","TARGETING"]\';\n            window.OneTrust = window.OneTrust || {};\n            window.OneTrust.dataSubjectParams = window.OneTrust.dataSubjectParams || {};\n            window.OneTrust.dataSubjectParams.id = \'\';\n            window.OneTrust.dataSubjectParams.isAnonymous = true;\n\n            function addCookieManagementScript() {\n                var tag = document.createElement(\'script\');\n                tag.async = true;\n                tag.src = \'https://cdn.cookielaw.org/consent/5fbcd417-fbc1-4fcc-abad-f622f1bba72d/otSDKStub.js\';\n                tag.type = \'text/javascript\';\n                tag.charset = \'UTF-8\';\n                tag.setAttribute(\'data-domain-script\', \'5fbcd417-fbc1-4fcc-abad-f622f1bba72d\');\n                tag.setAttribute(\'data-document-language\', \'true\');\n\n                document.head.appendChild(tag);\n            }\n\n            if (\'requestIdleCallback\' in window) {\n                requestIdleCallback(addCookieManagementScript, { timeout: 4000 });\n            } else {\n                setTimeout(addCookieManagementScript, 2000);\n            }\n        </script><script async src="https://www.google-analytics.com/analytics.js"></script><script async src="https://www.googletagmanager.com/gtag/js?id=G-K9Z2ZEVC8C&l=ga4DataLayer"></script><script>window.ga4DataLayer=window.ga4DataLayer||[];function ga4Tag(){ga4DataLayer.push(arguments);};ga4Tag("js",new Date());ga4Tag("config","G-K9Z2ZEVC8C",{send_page_view:false});</script><meta id="emotion-container"><style data-emotion-css="0 xl0fej ymzf9m zar4qi 1b3m20f 39ydts 1d8ba7q 13merx8 e29med qyp8bo 1nrzw89 w8rns 1j8qci xlzvdl 1sb02f4 19v1rkv 148iqgq chan6m qgunke 1egxyvc 1idmmu3 sw4sjz 1v6h3fb 12i50in 6a0jil 12il5ah 7z2yta 1llfbb7 aurft1 z8bp47 1r871ch 1x88bq4 1jr0qsc 1qjitbm ux5mu6 1evauet 1iuvwzi omlvsn 1enow5j ije6j5 1pz4y59 1fnccdf 19sk4h4 f4x8dl 92lxig 1m77lek 9vivtc 10k63u1 1xvm99p 1u89q5b wonnhn 1mzdwiy 11ydgmk vzslx5 1oibaro vently 1mstc1q 1hqkluu 1afdtvl 1nx1n9o 3u4ty 18uwsbz rom85o inq9gi 1c2abjj 1u3lomw 1lr1m88 15pl05a 1mlfcyf qevnix x1fp9c gutk1c vzkfjm 15j7fnr war30n na3oda ed2ruq foyide 1lx34my ahgoya 1kq79li ncv51b 79elbk 1rjq8gp 16agjqd 174w6ul gnym5v fkyaap rvoh79 160jk0r 1nzu07n 1c994ch 1dvzjst 1th0cu9 1hyrt2g 1btloax 8rlg7e 12oxox4 1e9ap21 1g3l7bp 1dozr91 1sbxp6g 1q3cf7o cgap95 4zp531 45sgf 1h0y4i5 xb3nz6 1jxkguo 182o411 ralh0w 1jac6c2 cwr0q8 ddqa90 fksa8h n65gq3 1vg9j2 147xtl9 11i4m5w f14jpt 1se8maq 1x9ee72 aplobz 18182hy 1fdy0l5 1cvbkpk 997a5u odjpwj 1jyrmsq 1t7f977 1qdduzb agyoef 1ytpb90 tza3mu 2sacua 1p9ibgf 106vfgv 1inzsq1 r9996t 1jtriov 29kerx 1hgawz4 syqjjh xxqqxs 4g6ai3 lziufc 1xkgsub w1k3wh ee59jl 1oiyjl1 lsbzdp 9zvmc3 1p80smk xp8w2v 1vhakgw 16y3sxf 1lnf5f9">html,body,div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...
# 3  Update: See the argumentative response from th...
# 4  I give this place a zero having an appointment...

# %%
# This code is to see how many reviews there are
len(df['review'])
# Out:
# 10

# %%
# Checking the lengths of each review along with word count
df['word_count'] = df['review'].apply(lambda x: len(x.split()))

# %%
df.head()
# Out:
#                                               review  word_count
# 0  The shape itself was fine but do not get any d...         131
# 1  I wanted to try this new salon so bad since it...         140
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105
# 3  Update: See the argumentative response from th...         104
# 4  I give this place a zero having an appointment...         107

# %%
# Counting the characters
df['char_count'] = df['review'].apply(lambda x: len (x))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553

# %%
# Finding the average word amount per review
def average_words(x):
    words = x.split() #this will give us the number of words
    return sum(len(word) for word in words) / len(words)

# %%
# Printing out the average words per review
df['average_word_length'] = df['review'].apply(lambda x:average_words(x))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length
# 0             4.007634
# 1             4.714286
# 2             4.600000
# 3             4.701923
# 4             4.177570

# %% [markdown]
# ## COUNTING STOP WORDS

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\trini\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
len(stop_words)
# Out:
# 179

# %%
# How many stop words are in our reviews?
df['stopword_count'] = df['review'].apply(lambda x: len([word for word in x.split() if word.lower() in stop_words]))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count
# 0             4.007634              69
# 1             4.714286              70
# 2             4.600000              46
# 3             4.701923              48
# 4             4.177570              62

# %%
df['stopword_rate'] = df['stopword_count'] / df['word_count']

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439

# %%
# sorting the stopword_rate by ascending order
df.sort_values(by='stopword_rate')
# Out:
#                                               review  word_count  char_count
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587  \
# 9  Biggest waste of time! Took 4 hours for a mani...          69         353
# 3  Update: See the argumentative response from th...         104         594
# 6  I was debating on posting this but it's still ...         458        2376
# 5  There are lots of nail places out there. Don't...          35         186
# 1  I wanted to try this new salon so bad since it...         140         799
# 7  Went with two other friends we asked for the s...         123         635
# 0  The shape itself was fine but do not get any d...         131         655
# 8  I made an appointment three days in advance fo...         176         918
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 2             4.600000              46       0.438095
# 9             4.130435              31       0.449275
# 3             4.701923              48       0.461538
# 6             4.189956             219       0.478166
# 5             4.342857              17       0.485714
# 1             4.714286              70       0.500000
# 7             4.170732              64       0.520325
# 0             4.007634              69       0.526718
# 8             4.176136              95       0.539773
# 4             4.177570              62       0.579439

# %%
df.describe()
# Out:
#        word_count  char_count  average_word_length  stopword_count
# count   10.000000    10.00000            10.000000       10.000000  \
# mean   144.800000   765.60000             4.321153       72.100000
# std    116.540694   601.82467             0.256887       56.048491
# min     35.000000   186.00000             4.007634       17.000000
# 25%    104.250000   561.50000             4.172083       46.500000
# 50%    115.000000   614.50000             4.183763       63.000000
# 75%    137.750000   763.00000             4.535714       69.750000
# max    458.000000  2376.00000             4.714286      219.000000
#
#        stopword_rate
# count      10.000000
# mean        0.497904
# std         0.044147
# min         0.438095
# 25%         0.465695
# 50%         0.492857
# 75%         0.525119
# max         0.579439

# %% [markdown]
# ## DATA CLEANING PROCESS

# %%
# lowercase each and every word in the review (makes it easier to remove stop words)
df['lowercase'] = df['review'].apply(lambda x: " ".join(word.lower() for word in x.split()))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718  \
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439
#
#                                            lowercase
# 0  the shape itself was fine but do not get any d...
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure? don't go to bui!! i ha...
# 3  update: see the argumentative response from th...
# 4  i give this place a zero having an appointment...

# %%
# Remove all punctuations 
import re
df['punctuation'] = df['lowercase'] = df['lowercase'].apply(lambda x: re.sub(r'[^\w\s]', '', x))

# %%
df['punctuation']
# Out:
# 0    the shape itself was fine but do not get any d...
# 1    i wanted to try this new salon so bad since it...
# 2    thinking of a pedicure dont go to bui i had a ...
# 3    update see the argumentative response from the...
# 4    i give this place a zero having an appointment...
# 5    there are lots of nail places out there dont p...
# 6    i was debating on posting this but its still t...
# 7    went with two other friends we asked for the s...
# 8    i made an appointment three days in advance fo...
# 9    biggest waste of time took 4 hours for a manip...
# Name: punctuation, dtype: object

# %%
# removing stop words
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('english')

# %%
# looping through each word in our review, if the word is not in the stop word list we will return it, if not it will not return
df['stopwords'] = df['punctuation'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718  \
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439
#
#                                            lowercase
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                          punctuation
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                            stopwords
# 0  shape fine get designs awful cheap looking cha...
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont go bui 12pm appointment...
# 3  update see argumentative response manager sayi...
# 4  give place zero appointment waiting call upset...

# %%
# creating an array of every single word of our reviews
pd.Series(" ". join(df['stopwords']).split()).value_counts()[:30] # by doing value_counts, it shows us how many times each word comes up in our reviews
# Out:
# nail            11
# nails           10
# said             9
# salon            8
# didnt            7
# time             7
# asked            6
# appointment      6
# dont             6
# back             6
# new              5
# one              5
# wait             5
# feel             5
# pedicure         5
# c                5
# charged          5
# know             5
# bad              5
# two              4
# go               4
# receptionist     4
# business         4
# week             4
# less             4
# came             4
# theres           4
# ive              4
# gel              4
# think            4
# Name: count, dtype: int64

# %%
other_stop_words = ['c', 'theres', 'ive', 'one', 'go', 'know', 'two', 'zero']

# %%
len(other_stop_words)
# Out:
# 8

# %%
# Only returning words that are not in other_stop_words
df['cleanreview'] = df['stopwords'].apply(lambda x: " ".join(word for word in x.split() if word not in other_stop_words))

# %%
pd.Series(" ".join(df['cleanreview']).split()).value_counts()[:30]
# Out:
# nail            11
# nails           10
# said             9
# salon            8
# time             7
# didnt            7
# back             6
# appointment      6
# dont             6
# asked            6
# new              5
# charged          5
# bad              5
# wait             5
# pedicure         5
# feel             5
# think            4
# came             4
# gel              4
# week             4
# receptionist     4
# business         4
# less             4
# still            4
# understand       4
# someone          4
# also             4
# looking          4
# place            3
# good             3
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718  \
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439
#
#                                            lowercase
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                          punctuation
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                            stopwords
# 0  shape fine get designs awful cheap looking cha...  \
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont go bui 12pm appointment...
# 3  update see argumentative response manager sayi...
# 4  give place zero appointment waiting call upset...
#
#                                          cleanreview
# 0  shape fine get designs awful cheap looking cha...
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont bui 12pm appointment di...
# 3  update see argumentative response manager sayi...
# 4  give place appointment waiting call upsetting ...

# %% [markdown]
# ## DOING LEMMATIZATION TO CONDENSE WORDS DOWN TO THEIR BASE FORMAT

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\trini\AppData\Roaming\nltk_data...
# True

# %%
from textblob import Word

# %%
df['lemmatized'] = df['cleanreview'].apply(lambda x: " ".join(Word(word).lemmatize() for word in x.split()))

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718  \
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439
#
#                                            lowercase
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                          punctuation
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                            stopwords
# 0  shape fine get designs awful cheap looking cha...  \
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont go bui 12pm appointment...
# 3  update see argumentative response manager sayi...
# 4  give place zero appointment waiting call upset...
#
#                                          cleanreview
# 0  shape fine get designs awful cheap looking cha...  \
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont bui 12pm appointment di...
# 3  update see argumentative response manager sayi...
# 4  give place appointment waiting call upsetting ...
#
#                                           lemmatized
# 0  shape fine get design awful cheap looking char...
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont bui 12pm appointment di...
# 3  update see argumentative response manager sayi...
# 4  give place appointment waiting call upsetting ...

# %% [markdown]
# ## SENTIMENT ANALYSIS

# %%
from textblob import TextBlob

# %%
df['polarity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df['subjectivity'] = df['lemmatized'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df.head()
# Out:
#                                               review  word_count  char_count
# 0  The shape itself was fine but do not get any d...         131         655  \
# 1  I wanted to try this new salon so bad since it...         140         799
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 3  Update: See the argumentative response from th...         104         594
# 4  I give this place a zero having an appointment...         107         553
#
#    average_word_length  stopword_count  stopword_rate
# 0             4.007634              69       0.526718  \
# 1             4.714286              70       0.500000
# 2             4.600000              46       0.438095
# 3             4.701923              48       0.461538
# 4             4.177570              62       0.579439
#
#                                            lowercase
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                          punctuation
# 0  the shape itself was fine but do not get any d...  \
# 1  i wanted to try this new salon so bad since it...
# 2  thinking of a pedicure dont go to bui i had a ...
# 3  update see the argumentative response from the...
# 4  i give this place a zero having an appointment...
#
#                                            stopwords
# 0  shape fine get designs awful cheap looking cha...  \
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont go bui 12pm appointment...
# 3  update see argumentative response manager sayi...
# 4  give place zero appointment waiting call upset...
#
#                                          cleanreview
# 0  shape fine get designs awful cheap looking cha...  \
# 1  wanted try new salon bad since new community r...
# 2  thinking pedicure dont bui 12pm appointment di...
# 3  update see argumentative response manager sayi...
# 4  give place appointment waiting call upsetting ...
#
#                                           lemmatized  polarity  subjectivity
# 0  shape fine get design awful cheap looking char...  0.128571      0.128571
# 1  wanted try new salon bad since new community r...  0.006612      0.006612
# 2  thinking pedicure dont bui 12pm appointment di...  0.137273      0.137273
# 3  update see argumentative response manager sayi...  0.456818      0.456818
# 4  give place appointment waiting call upsetting ...  0.200000      0.200000

# %%
# Dropping columns we don't need
df.drop(['lowercase', 'punctuation', 'stopwords', 'cleanreview', 'lemmatized'], axis=1, inplace=True)

# %%
df.sort_values(by='polarity')
# Out:
#                                               review  word_count  char_count
# 5  There are lots of nail places out there. Don't...          35         186  \
# 8  I made an appointment three days in advance fo...         176         918
# 6  I was debating on posting this but it's still ...         458        2376
# 1  I wanted to try this new salon so bad since it...         140         799
# 0  The shape itself was fine but do not get any d...         131         655
# 2  Thinking of a pedicure? DON'T go to BUI!! I ha...         105         587
# 7  Went with two other friends we asked for the s...         123         635
# 9  Biggest waste of time! Took 4 hours for a mani...          69         353
# 4  I give this place a zero having an appointment...         107         553
# 3  Update: See the argumentative response from th...         104         594
#
#    average_word_length  stopword_count  stopword_rate  polarity  subjectivity
# 5             4.342857              17       0.485714 -0.132727     -0.132727
# 8             4.176136              95       0.539773 -0.054895     -0.054895
# 6             4.189956             219       0.478166 -0.002017     -0.002017
# 1             4.714286              70       0.500000  0.006612      0.006612
# 0             4.007634              69       0.526718  0.128571      0.128571
# 2             4.600000              46       0.438095  0.137273      0.137273
# 7             4.170732              64       0.520325  0.160000      0.160000
# 9             4.130435              31       0.449275  0.200000      0.200000
# 4             4.177570              62       0.579439  0.200000      0.200000
# 3             4.701923              48       0.461538  0.456818      0.456818
